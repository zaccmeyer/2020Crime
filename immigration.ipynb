# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint, solve_ivp, solve_bvp
from scipy.optimize import minimize

# %%
def prob1():
    '''
    Using the SIR model, model the spread of a disease in a city
    of 3 million people where there are initially 5 infected
    people.

    1. Plot the results
    2. Find the number of people still able to work at peak infection
    '''
    t0 = 0 
    tf = 36
    n = 44000000
    beta = 1
    gamma = 1/3

    # define the ode system as given in the problem
    def ode(t,y):
        return np.array([-beta*y[0]*y[1], beta*y[0]*y[1]-gamma*y[1],gamma*y[1]])
    
    # define the initial conditions
    y0 = np.array([(n-5)/n,5/n,0])
    # solve the system
    sol = solve_ivp(ode, (t0,tf), y0, t_eval=np.linspace(t0, tf, 150))
    
    # Plot the system and label/title everything
    plt.plot(sol.t,sol.y[0],label='Ukrainian Citizens in Ukraine')
    plt.plot(sol.t,sol.y[1],label='Citizens Moving')
    plt.plot(sol.t,sol.y[2],label='Ukrainian Citizens who Emigrated')
    plt.xlabel('T (Monts)')
    plt.ylabel('Proportion of Population')
    plt.title('Ukrainian Model')
    plt.legend()
    plt.show()

# %%
prob1()

# %%
def prob1_b():
    '''
    Using the SIR model, model the spread of a disease in a city
    of 3 million people where there are initially 5 infected
    people.

    1. Plot the results
    2. Find the number of people still able to work at peak infection
    '''
    t0 = 0 
    tf = 36
    n = 44000000
    beta = 10
    gamma = 2

    # define the ode system as given in the problem
    def ode(t,y):
        return np.array([-beta*y[0]*y[1], beta*y[0]*y[1]-gamma*y[1],gamma*y[1]])
    
    # define the initial conditions
    y0 = np.array([(n-5)/n,5/n,0])
    # solve the system
    sol = solve_ivp(ode, (t0,tf), y0, t_eval=np.linspace(t0, tf, 150))
    
    # Plot the system and label/title everything
    plt.plot(sol.t,sol.y[0],label='Ukrainian Citizens in Ukraine')
    plt.plot(sol.t,sol.y[1],label='Citizens Moving')
    plt.plot(sol.t,sol.y[2],label='Ukrainian Citizens who Emigrated')
    plt.xlabel('T (Monts)')
    plt.ylabel('Proportion of Population')
    plt.title('Ukrainian Model')
    plt.legend()
    plt.show()

# %%
prob1_b()

# %%
def prob1_c():
    '''
    Using the SIR model, model the spread of a disease in a city
    of 3 million people where there are initially 5 infected
    people.

    1. Plot the results
    2. Find the number of people still able to work at peak infection
    '''
    t0 = 0 
    tf = 36
    n = 44000000
    beta = 5
    gamma = 1.5

    # define the ode system as given in the problem
    def ode(t,y):
        return np.array([-beta*y[0]*y[1], beta*y[0]*y[1]-gamma*y[1],gamma*y[1]])
    
    # define the initial conditions
    y0 = np.array([(n-100)/n,100/n,0])
    # solve the system
    sol = solve_ivp(ode, (t0,tf), y0, t_eval=np.linspace(t0, tf, 150))
    
    # Plot the system and label/title everything
    plt.plot(sol.t,sol.y[0],label='Ukrainian Citizens in Ukraine')
    plt.plot(sol.t,sol.y[1],label='Citizens Moving')
    plt.plot(sol.t,sol.y[2],label='Ukrainian Citizens who Emigrated')
    plt.xlabel('T (Monts)')
    plt.ylabel('Proportion of Population')
    plt.title('Ukrainian Model')
    plt.legend()
    plt.show()

# %%
prob1_c()

# %%
def prob2():
    '''
    Using the SIR model, model the spread of a disease in a city
    of 3 million people where there are initially 5 infected
    people.

    1. Plot the results
    2. Find the number of people still able to work at peak infection
    '''
    t0 = 0 
    tf = 36
    n = 44000000
    beta = 1
    gamma = 1/3
    birth = .001
    death = .01

    # define the ode system as given in the problem
    def ode(t,y):
        return np.array([-beta*y[0]*y[1]+birth*y[0]-death*y[0], beta*y[0]*y[1]-gamma*y[1],gamma*y[1]])
    
    # define the initial conditions
    y0 = np.array([(n-5)/n,5/n,0])
    # solve the system
    sol = solve_ivp(ode, (t0,tf), y0, t_eval=np.linspace(t0, tf, 150))
    
    # Plot the system and label/title everything
    plt.plot(sol.t,sol.y[0],label='Ukrainian Citizens in Ukraine')
    plt.plot(sol.t,sol.y[1],label='Citizens Moving')
    plt.plot(sol.t,sol.y[2],label='Ukrainian Citizens who Emigrated')
    plt.xlabel('T (Monts)')
    plt.ylabel('Proportion of Population')
    plt.title('Ukrainian Model')
    plt.legend()
    plt.show()

# %%
prob2()

# %%
def prob3():
    '''
    Using the SIR model, model the spread of a disease in a city
    of 3 million people where there are initially 5 infected
    people.

    1. Plot the results
    2. Find the number of people still able to work at peak infection
    '''
    t0 = 0 
    tf = 36
    n = 44000000
    beta = 5
    gamma = 1.5
    birth = .001
    death = .01
    k = 33000000/n
    # print(k)
    # birth*y[0]-death*y[0]

    # define the ode system as given in the problem
    def ode(t,y):
        return np.array([-beta*y[0]*y[1]*(1-(y[0]/k)), beta*y[0]*y[1]-gamma*y[1],gamma*y[1]])
    
    # define the initial conditions
    y0 = np.array([(n-100)/n,100/n,0])
    # solve the system
    sol = solve_ivp(ode, (t0,tf), y0, t_eval=np.linspace(t0, tf, 150))
    
    # Plot the system and label/title everything
    plt.plot(sol.t,sol.y[0],label='Ukrainian Citizens in Ukraine')
    plt.plot(sol.t,sol.y[1],label='Citizens Moving')
    plt.plot(sol.t,sol.y[2],label='Ukrainian Citizens who Emigrated')
    plt.xlabel('T (Monts)')
    plt.ylabel('Proportion of Population')
    plt.title('Ukrainian Model')
    plt.legend()
    plt.show()

# %%
prob3()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/zacmeyer/Downloads/ACME Projects/2020Crime/immigration.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/Users/zacmeyer/Downloads/ACME%20Projects/2020Crime/immigration.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> prob3()
#
# /Users/zacmeyer/Downloads/ACME Projects/2020Crime/immigration.ipynb Cell 11 line 2
#      <a href='vscode-notebook-cell:/Users/zacmeyer/Downloads/ACME%20Projects/2020Crime/immigration.ipynb#W6sZmlsZQ%3D%3D?line=25'>26</a> y0 = np.array([(n-100)/n,100/n,0])
#      <a href='vscode-notebook-cell:/Users/zacmeyer/Downloads/ACME%20Projects/2020Crime/immigration.ipynb#W6sZmlsZQ%3D%3D?line=26'>27</a> # solve the system
# ---> <a href='vscode-notebook-cell:/Users/zacmeyer/Downloads/ACME%20Projects/2020Crime/immigration.ipynb#W6sZmlsZQ%3D%3D?line=27'>28</a> sol = solve_ivp(ode, (t0,tf), y0, t_eval=np.linspace(t0, tf, 150))
#      <a href='vscode-notebook-cell:/Users/zacmeyer/Downloads/ACME%20Projects/2020Crime/immigration.ipynb#W6sZmlsZQ%3D%3D?line=29'>30</a> # Plot the system and label/title everything
#      <a href='vscode-notebook-cell:/Users/zacmeyer/Downloads/ACME%20Projects/2020Crime/immigration.ipynb#W6sZmlsZQ%3D%3D?line=30'>31</a> plt.plot(sol.t,sol.y[0],label='Ukrainian Citizens in Ukraine')
#
# File /opt/homebrew/lib/python3.10/site-packages/scipy/integrate/_ivp/ivp.py:591, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     589 status = None
#     590 while status is None:
# --> 591     message = solver.step()
#     593     if solver.status == 'finished':
#     594         status = 0
#
# File /opt/homebrew/lib/python3.10/site-packages/scipy/integrate/_ivp/base.py:181, in OdeSolver.step(self)
#     179 else:
#     180     t = self.t
# --> 181     success, message = self._step_impl()
#     183     if not success:
#     184         self.status = 'failed'
#
# File /opt/homebrew/lib/python3.10/site-packages/scipy/integrate/_ivp/rk.py:144, in RungeKutta._step_impl(self)
#     141 h = t_new - t
#     142 h_abs = np.abs(h)
# --> 144 y_new, f_new = rk_step(self.fun, t, y, self.f, h, self.A,
#     145                        self.B, self.C, self.K)
#     146 scale = atol + np.maximum(np.abs(y), np.abs(y_new)) * rtol
#     147 error_norm = self._estimate_error_norm(self.K, h, scale)
#
# File /opt/homebrew/lib/python3.10/site-packages/scipy/integrate/_ivp/rk.py:64, in rk_step(fun, t, y, f, h, A, B, C, K)
#      62 for s, (a, c) in enumerate(zip(A[1:], C[1:]), start=1):
#      63     dy = np.dot(K[:s].T, a[:s]) * h
# ---> 64     K[s] = fun(t + c * h, y + dy)
#      66 y_new = y + h * np.dot(K[:-1].T, B)
#      67 f_new = fun(t + h, y_new)
#
# KeyboardInterrupt:
