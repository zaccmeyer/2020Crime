# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML
import matplotlib.ticker as ticker
import numpy.linalg as la
from skspatial.objects import Sphere

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
# Number of points in the sine wave
num_points = 1000

# Parametric values, from 0 to 1
z = np.linspace(0, 15, num_points)

# Define the path from (0,0,0) to (1,1,1)
x = np.sin(z)
y = np.cos(z)
#z = t
# Apply a sine wave along the path
amp = 0.1  # Adjust the amplitude as needed
freq = 0.2  # Adjust the frequency as needed

ax.scatter(0,1,0, marker = '^', label = 'rocket', s = 50)
ax.scatter(0.65,-0.7596,15.0, marker = '*', label = 'space station')
ax.plot(1.03,0.09,1.6,marker = 'o', color = 'gray', markersize = 10)
ax.plot(.16,-1.02,3.5,marker = 'o', color = 'gray', markersize = 15)
ax.plot(-.3,-.3,10,marker = 'o', color = 'gray', markersize = 8)
ax.plot(-1.1,-0.25,4.6, color = 'gray',marker = 'o')

ax.plot(-.3,1,6.1, color = 'gray',marker = 'o')
ax.plot(1,.35,7.6, color = 'gray',marker = 'o')
ax.plot(.41,-0.92,9.1, color = 'gray',marker = 'o')
ax.plot(-.9,-.47,10.55, color = 'gray',marker = 'o')

plt.Sphere(-0.55, 0.86, 12.2, color = 'gray',marker = 'o')
plt.Sphere(-0.55, 0.86, 12.2, color = 'gray', marker = 'o')
ax.scatter(0.82, 0.59, 13.52, color = 'gray', marker = 'o', label = 'Asteroid')

#ax.plot(0,1,0, color = 'red')
# Plot the sine wave in 3D
ax.plot3D(x, y, z, color = 'crimson')
#create limits and tick markings for your 3 plot
plt.legend()
plt.title('Hypothetical 3d Path to a Space Station')
plt.show()
